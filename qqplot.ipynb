# %% [markdown]
# # Custom QQ
# Maybe something wrong

# %%
import numpy as np
from matplotlib import pyplot as plt
import scipy.stats

# %%
np.random.seed(1)
x = np.linspace(0,100,200)
y = 3.0 * x + np.random.normal(scale=60,size=len(x))
y = 3.0 * x + 0.1*x**2 + np.random.normal(scale=60,size=len(x))

# %%
plt.plot(x,y)

# %%
slope, intercept, _,_,_ = scipy.stats.linregress(x,y)

# %%
yhat = slope * x + intercept

# %%
plt.plot(x,y)
plt.plot(x,yhat)

# %%
res = y - yhat

# %%
plt.plot(res)

# %%
plt.hist(res)
# Out:
# (array([ 8., 24., 32., 43., 37., 26., 13., 10.,  5.,  2.]),
#  array([-1.96280583e+02, -1.47237156e+02, -9.81937289e+01, -4.91503018e+01,
#         -1.06874732e-01,  4.89365524e+01,  9.79799794e+01,  1.47023407e+02,
#          1.96066834e+02,  2.45110261e+02,  2.94153688e+02]),
#  <a list of 10 Patch objects>)

# %%
percentile_data = np.percentile(res, q=np.linspace(0,100,1000))

# %%
_= scipy.stats.probplot(res, plot=plt)

# %%
percentile_norm = np.percentile(np.random.normal(size=20000), q=np.linspace(0,100,1000))

# %%
ax.get_ylim()
# Out:
# (-247.77618153862244, 345.64928625566756)

# %%
# custom qq plot
fig, ax = plt.subplots()
ax.plot(percentile_norm, percentile_data)
ax.plot(ax.get_xlim(), ax.get_ylim())
#ax.
#plt.plot()

# %%
percentile_norm
# Out:
# array([-2.79308500e+00, -1.76068856e+00, -1.67419581e+00, -1.65072127e+00,
#        -1.52568032e+00, -1.44087602e+00, -1.39662042e+00, -1.34267579e+00,
#        -1.33195167e+00, -1.30572692e+00, -1.23685338e+00, -1.23312074e+00,
#        -1.21974440e+00, -1.18231813e+00, -1.11911540e+00, -1.11647002e+00,
#        -1.04458938e+00, -9.55425262e-01, -8.90555584e-01, -8.77281519e-01,
#        -8.67787223e-01, -8.61316361e-01, -7.81911683e-01, -7.33271604e-01,
#        -7.00398505e-01, -6.80678141e-01, -6.65754518e-01, -6.06998398e-01,
#        -5.86523939e-01, -5.62305431e-01, -5.45774168e-01, -4.98213564e-01,
#        -4.43171931e-01, -4.37508983e-01, -4.34956683e-01, -4.00878192e-01,
#        -3.74438319e-01, -3.44987210e-01, -3.26499498e-01, -3.10984978e-01,
#        -2.97361883e-01, -2.54179868e-01, -2.30839743e-01, -2.03394449e-01,
#        -1.98837863e-01, -1.86578994e-01, -1.20464572e-01, -8.45080274e-02,
# ...
